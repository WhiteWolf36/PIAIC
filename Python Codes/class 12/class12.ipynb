# %%
print("logic1")
print("logic2")
l1: list[int] = [1, 2, 3]

try:
    print(7 / 0)
    print(l1[0])

except ZeroDivisionError:
    print("Zero division error")


except IndexError:
    print("Index error")

print("logic3")
# Out:
# logic1
# logic2
# Zero division error
# logic3

# %%
print("logic1")
print("logic2")
l1: list[int] = [1, 2, 3]

try:
    print(7 / 2)
    print(l1[4])

except ZeroDivisionError:
    print("Zero division error")


except IndexError:
    print("Index error")

print("logic3")
# Out:
# logic1
# logic2
# 3.5
# Index error
# logic3

# %%
print("logic1")
print("logic2")
l1: list[int] = [1, 2, 3]

try:
    print(7 / 2)
    print(l1[2])
    open("aa.txt")

except ZeroDivisionError:
    print("Zero division error")


except IndexError:
    print("Index error")

except:  # Dynamic Except Which we dont know about
    print("Unknown error")

print("logic3")
# Out:
# logic1
# logic2
# 3.5
# 3
# Unknown error
# logic3

# %%
try:
    print(age)

except Exception as e:
    print(f"Something is wrong!\n{e}")
# Out:
# Something is wrong!
# name 'age' is not defined

# %%
try:
    print(l1[100])

except Exception as e:
    print(f"Something is wrong!\n{e}")
# Out:
# Something is wrong!
# list index out of range

# %%
class StudentCard:
    def __init__(self, roll_no: int, name: str, age: int) -> None:
        if age < 18 or age > 60:
            raise StudentClassError("You are not eligible for this program")
        self.roll_no = roll_no
        self.name = name
        self.age = age


class StudentClassError(Exception):
    pass


student1 = StudentCard(1, "Ahmad", 30)

print(student1.age, student1.roll_no, student1.name)
# Out:
# 30 1 Ahmad

# %%
student2 = StudentCard(2, "Ali", 12)

print(student1.age, student1.roll_no, student1.name)
# Out:
# ---------------------------------------------------------------------------
# StudentClassError                         Traceback (most recent call last)
# c:\Users\Administrator\Documents\PIAIC\Python Codes\class 12\class12.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> student2 = StudentCard(2, 'Ali', 12)
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> print(student1.age, student1.roll_no, student1.name)
#
# c:\Users\Administrator\Documents\PIAIC\Python Codes\class 12\class12.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> def __init__(self, roll_no: int, name: str, age: int) -> None:
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     if age < 18 or age > 60:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>         raise StudentClassError("You are not eligible for this program")
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     self.roll_no = roll_no
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     self.name = name
#
# StudentClassError: You are not eligible for this program

# %% [markdown]
# # File Handling
#
# https://www.geeksforgeeks.org/reading-writing-text-files-python/
#
# <img src="data:image/png;base64,...">

# %%
open("./abc.txt")
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='utf-8'>

# %%
from typing import TextIO

data: TextIO = open("./abc.txt")  # connectivity with abc.txt file
print(type(data))
data
# Out:
# <class '_io.TextIOWrapper'>
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='utf-8'>

# %%
[i for i in dir(data) if "__" not in i]
# Out:
# ['_CHUNK_SIZE',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
data: TextIO = open("./abc.txt")  # connectivity with abc.txt file
print(data.read())
# Out:
# line1
# line2

# %%
from typing import TextIO

data: TextIO = open("./abc.txt")  # connectivity with abc.txt file
print(data.read())  # we must close the connection
# with the file to free the resurce
data.close()
# Out:
# line1
# line2

# %% [markdown]
# ## With block automatically closes the file

# %%
with open("./abc.txt") as file:  # type : TextIO  default
    print(file.read())
# Out:
# line1
# line2

# %%
with open("./abc.txt") as file:  # type : TextIO  default
    print(file.readline())
    print(file.readline())
# Out:
# line1
#
# line2

# %%
with open("./abc.txt") as file:  # type : TextIO  default
    print(file.readline(), end="")
    print(file.readline())
# Out:
# line1
# line2

# %%
with open("./abc.txt") as file:  # type : TextIO  default
    print(file.readlines())
# Out:
# ['line1\n', 'line2\n', 'line3\n', 'line4\n', 'line5']

# %%
with open("./abc.txt") as file:  # type : TextIO  default
    print(file.readlines()[:3])
# Out:
# ['line1\n', 'line2\n', 'line3\n']

# %%
with open("./abc.txt", "r") as file:  # type : TextIO  default and r is default
    print(file.readlines()[:3])
# Out:
# ['line1\n', 'line2\n', 'line3\n']

# %%
with open("./abc.txt", "r") as file:  # type : TextIO  default and r is default
    print(file.read())
    print(file.write("Pakistan Zindabad"))
# Out:
# line1
# line2
# line3
# line4
# line5
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# c:\Users\Administrator\Documents\PIAIC\Python Codes\class 12\class12.ipynb Cell 21 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> with open("./abc.txt", "r") as file:  # type : TextIO  default and r is default
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a>     print(file.read())
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a>     print(file.write("Pakistan Zindabad"))
#
# UnsupportedOperation: not writable

# %%
with open("./abc.txt", "w") as file:  # type : TextIO  default and r is default
    print(file.read())
    print(file.write("Pakistan Zindabad"))
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# c:\Users\Administrator\Documents\PIAIC\Python Codes\class 12\class12.ipynb Cell 22 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> with open("./abc.txt", "w") as file:  # type : TextIO  default and r is default
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a>     print(file.read())
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a>     print(file.write("Pakistan Zindabad"))
#
# UnsupportedOperation: not readable

# %%
with open("./abc1.txt", "w") as file:  # type : TextIO  default
    # and r is default
    file.write("Pakistan Zindabad")  # Removes the previous text
# Out:
# 17

# %%
with open("./abc1.txt", "r+") as file:  # type : TextIO  default and r is default
    print(file.read())
    file.write("We Love our country")

# %%
with open("./abc1.txt", "r+") as file:  # type : TextIO  default and r is default
    file.write("We Love our country")
    print(file.read())

# %%
with open("./abc1.txt", "r+") as file:  # type : TextIO  default and r is default
    print(file.read())
    file.write("We love our country")
    print(file.read())
# Out:
# Pakistan Zindabad

# %%
with open("./abc1.txt", "r+") as file:  # type : TextIO  default and r is default
    print(file.read())
    file.write("We love our country")
    file.seek(0)
    print(file.read())
# Out:
# Pakistan Zindaabad
# Pakistan ZindaabadWe love our country

# %% [markdown]
# # Now change modes

# %%
with open("./abc2.txt", "r") as file:  # type : TextIO  default
    # and r is default
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Administrator\Documents\PIAIC\Python Codes\class 12\class12.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> with open("./abc2.txt", "r") as file:  # type : TextIO  default
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a>     # and r is default
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a>     print(file.read())
#
# File c:\ProgramData\anaconda3\envs\python12\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './abc2.txt'

# %%
with open("./abc2.txt", "w") as file:
    print(file.write("Pakistan"))

# if file exist then it overwrite the file
# if no file it will create a new file

# %%
with open("./abc2.txt", "w") as file:
    print(file.write("Pakistan Zindaabad"))

# if file exist then it overwrite the file
# if no file it will create a new file
# Out:
# 18

# %%
with open("./abc2.txt", "a") as file:
    file.write(" Pakistan Zindaabad")

# if file exist then it does not overwrite the file
# if no file it will create a new file
# Out:
# 19

# %%
with open("./abc2.txt", "x") as file:
    print(file.write("Pakistan Zindaabad"))

# only create a new file everytime
# if file exists then error
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# c:\Users\Administrator\Documents\PIAIC\Python Codes\class 12\class12.ipynb Cell 33 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> with open("./abc2.txt", "x") as file:
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X50sZmlsZQ%3D%3D?line=1'>2</a>     print(file.write("Pakistan Zindaabad"))
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X50sZmlsZQ%3D%3D?line=3'>4</a> # if file exist then it overwrite the file
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/PIAIC/Python%20Codes/class%2012/class12.ipynb#X50sZmlsZQ%3D%3D?line=4'>5</a> # if no file it will create a new file
#
# File c:\ProgramData\anaconda3\envs\python12\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: './abc2.txt'

# %%
with open("./abc3.txt", "x") as file:
    file.write("Pakistan Zindaabad")

# only create a new file everytime
# if file exists then error

# %%
with open("./abc3.txt", "rb+") as file:
    print(file.read())
# Out:
# b'Pakistan Zindaabad'

# %% [markdown]
# <table class="s-table">
# <thead>
# <tr>
# <th style="text-align: center;">Mode</th>
# <th style="text-align: center;">r</th>
# <th style="text-align: center;">r+</th>
# <th style="text-align: center;">w</th>
# <th style="text-align: center;">w+</th>
# <th style="text-align: center;">a</th>
# <th style="text-align: center;">a+</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align: center;">Read</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Write</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Create</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Cover</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# </tr>
# <tr>
# <td style="text-align: center;">Point in the beginning</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# </tr>
# <tr>
# <td style="text-align: center;">Point in the end</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# # read some real world data files
#
# - image
# - csv
# - live camera

# %%
import pandas as pd

df: pd.DataFrame = pd.read_csv("./data.csv")
df
# Out:
#    id     name   education
# 0   1  'ahmad'  'Bachelor'
# 1   2    'ali'     'inter'
# 2   3  'qasim'    'Master'

# %%
import pandas as pd

df: pd.DataFrame = pd.read_excel("./demo.xlsx")
df
# Out:
#    Id   Name  Education
# 0   1  Ahmad  Bachelors
# 1   2    Ali      Inter
# 2   3  Qasim    Masters

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("gojo.jpg")

plt.imshow(img)

# %%
import fitz  # PyMuPDF


def read_pdf(pdf_path: str) -> str:
    text = ""
    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate through the pages
    for page_number in range(pdf_document.page_count):
        page = pdf_document.load_page(page_number)

        # Extract text from the page
        page_text = page.get_text()

        # Append the page's text to the result
        text += page_text

    # Close the PDF document
    pdf_document.close()

    return text


if __name__ == "__main__":
    pdf_path = "main.pdf"
    extracted_text = read_pdf(pdf_path)

    # Print or process the extracted text as needed
    print(extracted_text)
# Out:
# Pakistan Zindabaad
#
#
#
#
# I love Pakistan
